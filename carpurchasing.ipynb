# %%
import warnings
warnings.simplefilter("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cars = pd.read_csv("Car_Purchasing_Data.csv")

# %%
cars.head()
# Out:
#      Customer Name                                    Customer e-mail Country  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu     USA
# 1    Harlan Barnes                                eu.dolor@diam.co.uk     USA
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...     USA
# 3  Jade Cunningham                            malesuada@dignissim.com     USA
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net     USA
#
#    Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0   42    62812.09301      11609.380910  238961.2505
# 1       0   41    66646.89292       9572.957136  530973.9078
# 2       1   43    53798.55112      11160.355060  638467.1773
# 3       1   58    79370.03798      14426.164850  548599.0524
# 4       1   57    59729.15130       5358.712177  560304.0671
#
#    Car Purchase Amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# ...

# %%
cars.shape
# Out:
# (500, 9)

# %%
cars
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#     Country  Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# ...

# %%
cars.plot(x='Annual Salary', y='Credit Card Debt',style='o' )    
plt.title('Annual Salary vs Credit Card Debt ')    
plt.xlabel('Annual Salary')    
plt.ylabel('Credit Card Debt')    
plt.show()

# %%
cars.plot(x='Age', y='Annual Salary',style='o' )    
plt.title('Age vs Annual Salary')    
plt.xlabel('Age')    
plt.ylabel('Annual Salary')    
plt.show()

# %%
cars.plot(x='Age', y='Credit Card Debt',style='o' )    
plt.title('Age vs Credit Card Debt')    
plt.xlabel('Age')    
plt.ylabel('Credit Card Debt')    
plt.show()

# %%
new_set = cars.drop(['Customer e-mail','Country','Gender','Annual Salary','Credit Card Debt'], axis=1)

# %%
new_set
# Out:
#        Customer Name  Age    Net Worth  Car Purchase Amount
# 0      Martina Avila   42  238961.2505          35321.45877
# 1      Harlan Barnes   41  530973.9078          45115.52566
# 2    Naomi Rodriquez   43  638467.1773          42925.70921
# 3    Jade Cunningham   58  548599.0524          67422.36313
# 4       Cedric Leach   57  560304.0671          55915.46248
# ..               ...  ...          ...                  ...
# 495           Walter   41  541670.1016          48901.44342
# 496            Vanna   38  360419.0988          31491.41457
# 497            Pearl   54  764531.3203          64147.28888
# 498             Nell   59  337826.6382          45442.15353
# 499            Marla   47  462946.4924          45107.22566
#
# [500 rows x 4 columns]

# %%
new_set.head()
# Out:
#      Customer Name  Age    Net Worth  Car Purchase Amount
# 0    Martina Avila   42  238961.2505          35321.45877
# 1    Harlan Barnes   41  530973.9078          45115.52566
# 2  Naomi Rodriquez   43  638467.1773          42925.70921
# 3  Jade Cunningham   58  548599.0524          67422.36313
# 4     Cedric Leach   57  560304.0671          55915.46248

# %%
x=new_set.iloc[:,0]

# %%
x.shape
# Out:
# (500,)

# %%
x=new_set.iloc[:,1].values.reshape(-1,1)

# %%
x.shape
# Out:
# (500, 1)

# %%
x
# Out:
# array([[42],
#        [41],
#        [43],
#        [58],
#        [57],
#        [57],
#        [47],
#        [50],
#        [47],
#        [43],
#        [50],
#        [53],
#        [44],
#        [48],
#        [55],
#        [53],
#        [45],
#        [48],
#        [52],
#        [59],
#        [52],
#        [48],
#        [46],
#        [47],
#        [40],
#        [53],
#        [28],
#        [56],
#        [46],
#        [40],
#        [33],
#        [40],
#        [51],
#        [51],
#        [46],
#        [51],
#        [50],
#        [22],
#        [51],
#        [48],
#        [42],
#        [46],
#        [38],
#        [39],
#        [61],
#        [55],
#        [42],
#        [51],
#        [41],
#        [40],
#        [41],
#        [56],
#        [46],
#        [37],
#        [52],
#        [57],
#        [34],
#        [43],
#        [50],
#        [42],
#        [42],
#        [42],
#        [55],
#        [53],
#        [53],
#        [43],
# ...

# %%
y = new_set.iloc[:,1]

# %%
y.shape
# Out:
# (500,)

# %%
y=new_set.iloc[:,2].values.reshape(-1,1)

# %%
y
# Out:
# array([[ 238961.2505 ],
#        [ 530973.9078 ],
#        [ 638467.1773 ],
#        [ 548599.0524 ],
#        [ 560304.0671 ],
#        [ 428485.3604 ],
#        [ 326373.1812 ],
#        [ 629312.4041 ],
#        [ 630059.0274 ],
#        [ 476643.3544 ],
#        [ 612738.6171 ],
#        [ 293862.5123 ],
#        [ 430907.1673 ],
#        [ 420322.0702 ],
#        [ 146344.8965 ],
#        [ 481433.4324 ],
#        [ 370356.2223 ],
#        [ 549443.5886 ],
#        [ 431098.9998 ],
#        [ 566022.1306 ],
#        [ 480588.2345 ],
#        [ 307226.0977 ],
#        [ 497526.4566 ],
#        [ 688466.0503 ],
#        [ 499086.3442 ],
#        [ 429440.3297 ],
#        [ 315775.3207 ],
#        [ 341691.9337 ],
#        [ 188032.0778 ],
#        [ 583230.976  ],
#        [ 319837.6593 ],
#        [ 486069.073  ],
#        [ 655934.4666 ],
#        [ 487435.964  ],
#        [ 215673.5384 ],
#        [ 612242.7755 ],
#        [ 430624.8142 ],
#        [ 326742.7352 ],
# ...

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (400, 1)

# %%
x_test.shape
# Out:
# (100, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([[431014.06607611],
#        [427599.06517816],
#        [424867.0644598 ],
#        [433063.06661488],
#        [423501.06410062],
#        [433063.06661488],
#        [428965.06553734],
#        [434429.06697405],
#        [435112.06715364],
#        [420086.06320268],
#        [429648.06571693],
#        [435795.06733323],
#        [424184.06428021],
#        [429648.06571693],
#        [428965.06553734],
#        [426916.06499857],
#        [426233.06481898],
#        [439893.06841077],
#        [427599.06517816],
#        [411890.0610476 ],
#        [431014.06607611],
#        [426233.06481898],
#        [429648.06571693],
#        [417354.06248432],
#        [434429.06697405],
#        [426916.06499857],
#        [429648.06571693],
#        [436478.06751282],
#        [428282.06535775],
#        [433063.06661488],
#        [426233.06481898],
#        [426233.06481898],
#        [433746.06679446],
#        [424867.0644598 ],
#        [435795.06733323],
# ...

# %%
plt.scatter(x,y, color = 'blue')
plt.plot(x_test,y_pred, color = 'red')
